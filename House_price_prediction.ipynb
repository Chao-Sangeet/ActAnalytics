# %%
Path= r"C:\Users\User\.cache\kagglehub\datasets\shree1992\housedata\versions\2"

# %%
try:
    df = pd.read_csv(Path)
    print("Data Loaded successfully")
    df.head()

except:
    print("Couldn't load data, check once!")
# Out:
# Couldn't load data, check once!

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\User\Downloads\house_price_prediction.csv"

# %%
df = pd.read_csv( path )

# %%
df.head(3)
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3        1.5         1340      7912
# 1  02-05-2014 00:00  2384000.0         5        2.5         3650      9050
# 2  02-05-2014 00:00   342000.0         3        2.0         1930     11947
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA

# %%
df.tail()
# Out:
#                   date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09-07-2014 00:00  308166.6667         3       1.75         1510
# 4596  09-07-2014 00:00  534333.3333         3       2.50         1460
# 4597  09-07-2014 00:00  416904.1667         3       2.50         3010
# 4598  10-07-2014 00:00  203400.0000         4       2.00         2090
# 4599  10-07-2014 00:00  220600.0000         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0      1954          1979     501 N 143rd St    Seattle
# ...

# %%
#Exploring Data

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe().sum()
# Out:
# price            2.914918e+07
# bedrooms         4.623310e+03
# bathrooms        4.617445e+03
# sqft_living      2.767255e+04
# sqft_lot         1.153878e+06
# floors           4.611050e+03
# waterfront       4.601092e+03
# view             4.605019e+03
# condition        4.620129e+03
# sqft_above       2.214943e+04
# sqft_basement    1.080622e+04
# yr_built         1.643852e+04
# yr_renovated     1.040102e+04
# dtype: float64

# %%
df.describe().T
# Out:
#                 count           mean            std     min        25%  \
# price          4600.0  551962.988473  563834.702547     0.0  322875.00
# bedrooms       4600.0       3.400870       0.908848     0.0       3.00
# bathrooms      4600.0       2.160815       0.783781     0.0       1.75
# sqft_living    4600.0    2139.346957     963.206916   370.0    1460.00
# sqft_lot       4600.0   14852.516087   35884.436145   638.0    5000.75
# floors         4600.0       1.512065       0.538288     1.0       1.00
# waterfront     4600.0       0.007174       0.084404     0.0       0.00
# view           4600.0       0.240652       0.778405     0.0       0.00
# condition      4600.0       3.451739       0.677230     1.0       3.00
# sqft_above     4600.0    1827.265435     862.168977   370.0    1190.00
# sqft_basement  4600.0     312.081522     464.137228     0.0       0.00
# yr_built       4600.0    1970.786304      29.731848  1900.0    1951.00
# ...

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#Data Selection and filtering

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df["country"]
# Out:
# 0       USA
# 1       USA
# 2       USA
# 3       USA
# 4       USA
#        ...
# 4595    USA
# 4596    USA
# 4597    USA
# 4598    USA
# 4599    USA
# Name: country, Length: 4600, dtype: object

# %%
df["country"].value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %%
df["bedrooms"].sum()
# Out:
# 15644

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3    2032
# 4    1531
# 2     566
# 5     353
# 6      61
# 1      38
# 7      14
# 8       2
# 0       2
# 9       1
# Name: count, dtype: int64

# %%
df.loc[1:2]
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1  02-05-2014 00:00  2384000.0         5        2.5         3650      9050
# 2  02-05-2014 00:00   342000.0         3        2.0         1930     11947
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
#
#    yr_renovated                    street     city  statezip country
# 1             0           709 W Blaine St  Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE     Kent  WA 98042     USA

# %%
#Data Cleaning

# %%
df.isnull()
# Out:
#        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.drop(columns=["waterfront", "view", "sqft_above"], inplace = True)

# %%
df.drop( columns=["sqft_basement"], inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# date             object
# price           float64
# bedrooms          int64
# bathrooms       float64
# sqft_living       int64
# sqft_lot          int64
# floors          float64
# condition         int64
# yr_built          int64
# yr_renovated      int64
# street           object
# city             object
# statezip         object
# country          object
# dtype: object

# %%
df.rename( columns={"price":"Cost"}, inplace=True )
df.columns
# Out:
# Index(['date', 'Cost', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df["Nation & Zip"] = df["statezip"]+df["country"]

# %%
df.columns
# Out:
# Index(['date', 'Cost', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country', 'Nation & Zip'],
#       dtype='object')

# %%
df["Nation & Zip"].sum()
# Out:
# 'WA 98133USAWA 98119USAWA 98042USAWA 98008USAWA 98052USAWA 98115USAWA 98052USAWA 98038USAWA 98045USAWA 98115USAWA 98155USAWA 98105USAWA 98074USAWA 98106USAWA 98105USAWA 98042USAWA 98007USAWA 98092USAWA 98198USAWA 98045USAWA 98115USAWA 98006USAWA 98102USAWA 98011USAWA 98125USAWA 98003USAWA 98136USAWA 98033USAWA 98029USAWA 98117USAWA 98034USAWA 98072USAWA 98115USAWA 98155USAWA 98092USAWA 98023USAWA 98107USAWA 98038USAWA 98166USAWA 98116USAWA 98024USAWA 98055USAWA 98155USAWA 98116USAWA 98106USAWA 98077USAWA 98027USAWA 98059USAWA 98107USAWA 98052USAWA 98027USAWA 98075USAWA 98115USAWA 98014USAWA 98011USAWA 98006USAWA 98092USAWA 98065USAWA 98199USAWA 98106USAWA 98065USAWA 98045USAWA 98059USAWA 98042USAWA 98059USAWA 98117USAWA 98027USAWA 98065USAWA 98053USAWA 98058USAWA 98092USAWA 98122USAWA 98122USAWA 98074USAWA 98033USAWA 98103USAWA 98112USAWA 98074USAWA 98005USAWA 98029USAWA 98027USAWA 98075USAWA 98118USAWA 98027USAWA 98034USAWA 98155USAWA 98112USAWA 98033USAWA 98136USAWA 98198USAWA 9803
# ...

# %%
df["Nation & Zip"].value_counts()
# Out:
# Nation & Zip
# WA 98103USA    148
# WA 98052USA    135
# WA 98117USA    132
# WA 98115USA    130
# WA 98006USA    110
#               ...
# WA 98047USA      6
# WA 98288USA      3
# WA 98050USA      2
# WA 98354USA      2
# WA 98068USA      1
# Name: count, Length: 77, dtype: int64

# %%
df["Nation & Zip"].value_counts().sum()
# Out:
# 4600

# %%
df["Cost"].mean()
# Out:
# 551962.9884730434

# %%
df["Cost"].median()
# Out:
# 460943.46155

# %%
df["Cost"].mode()
# Out:
# 0    0.0
# Name: Cost, dtype: float64

# %%
#types

# %%
df.dtypes
# Out:
# date             object
# Cost            float64
# bedrooms          int64
# bathrooms       float64
# sqft_living       int64
# sqft_lot          int64
# floors          float64
# condition         int64
# yr_built          int64
# yr_renovated      int64
# street           object
# city             object
# statezip         object
# country          object
# Nation & Zip     object
# dtype: object

# %%
df.drop( columns=["country", "statezip"], inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'Cost', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built', 'yr_renovated', 'street', 'city',
#        'Nation & Zip'],
#       dtype='object')

# %%
#Visulaization

# %%
#Boxplot

sns.boxplot(x="bedrooms", y="Cost", data=df)
plt.title("House Prediction")
plt.show()

# %%
sns.scatterplot(x="bedrooms", y="Cost", data=df)
plt.show()

# %%
plt.hist(df["bedrooms"],color="red")
plt.title("House Prediction")
plt.show()

# %%
#Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
df.columns
# Out:
# Index(['date', 'Cost', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built', 'yr_renovated', 'street', 'city',
#        'Nation & Zip'],
#       dtype='object')

# %%
#Split Data

x = df[["bedrooms", "bathrooms"]]
y = df["Cost"]

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42 )

# %%
#Linear Regression

model = LinearRegression()
model.fit( x_train, y_train)
print("Prediction:", model.predict( x_test ))
# Out:
# Prediction: [ 613243.9761412   604312.40641056  783534.00455611  613243.9761412
#   613243.9761412   637159.86267836  466869.83426345  637159.86267836
#   580396.51987339  580396.51987339  693923.20548333  248748.03277421
#   637159.86267836  296579.80584854  442953.94772629  968808.34977754
#   750686.5482883   613243.9761412   442953.94772629  637159.86267836
#   670007.31894617  637159.86267836  442953.94772629  637159.86267836
#   362274.71838415  248748.03277421  613243.9761412   637159.86267836
#   419038.06118912  499717.29053126 1163014.26472962  419038.06118912
#  1261556.63353304  774602.43482547  466869.83426345  717839.0920205
#   637159.86267836 1446830.97875447  272663.91931138  613243.9761412
#   613243.9761412   442953.94772629  523633.17706842  466869.83426345
#   386190.60492132  386190.60492132  499717.29053126  547549.06360558
#   831365.77763044  693923.20548333  888129.12043541  783534.00455611
# ...

# %%
#Logistic Regression

# %%
model_1 = LogisticRegression()
model_1 = model.fit( x_train, y_train )
print("Prediction:", model_1.predict( x_test ))
# Out:
# Prediction: [ 613243.9761412   604312.40641056  783534.00455611  613243.9761412
#   613243.9761412   637159.86267836  466869.83426345  637159.86267836
#   580396.51987339  580396.51987339  693923.20548333  248748.03277421
#   637159.86267836  296579.80584854  442953.94772629  968808.34977754
#   750686.5482883   613243.9761412   442953.94772629  637159.86267836
#   670007.31894617  637159.86267836  442953.94772629  637159.86267836
#   362274.71838415  248748.03277421  613243.9761412   637159.86267836
#   419038.06118912  499717.29053126 1163014.26472962  419038.06118912
#  1261556.63353304  774602.43482547  466869.83426345  717839.0920205
#   637159.86267836 1446830.97875447  272663.91931138  613243.9761412
#   613243.9761412   442953.94772629  523633.17706842  466869.83426345
#   386190.60492132  386190.60492132  499717.29053126  547549.06360558
#   831365.77763044  693923.20548333  888129.12043541  783534.00455611
# ...
